# %% [markdown]
# <a href="https://colab.research.google.com/github/mehulpatil23/Favorita-Store-Sales-Forecasting/blob/main/CV_mock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('small_cat.jpg')

# %%
plt.imshow(img)

# %%
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_color)
